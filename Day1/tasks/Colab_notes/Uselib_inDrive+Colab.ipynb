# %%
#Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/SoftwareChecks.ipynb"

#Add the Notebook Path to Python's Search Path
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/SoftwareChecks.ipynb'

# %%
# !jupyter nbconvert --to python "/content/drive/MyDrive/Colab Notebooks/SoftwareChecks.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/SoftwareChecks.ipynb to python
# [NbConvertApp] Writing 223 bytes to /content/drive/MyDrive/Colab Notebooks/SoftwareChecks.py

# %%
import SoftwareChecks as lib

# %%
lib.function(2,3)
# Out:
# 6
